# %% [markdown]
# ---
# title: Elasticsearch with a simple Linear Learning to Rank Model
# author: doug-turnbull
# excerpt: "This blog post I want to take the simple model we derived in a previous post and make it usable via the Elasticsearch Learning to Rank plugin."
# categories:
#   - Relevancy
#   - Learning-to-rank
#   - Machine-Learning
# ---

# %% [markdown]
# [Last time](http://opensourceconnections.com/blog/2017/04/01/learning-to-rank-linear-models/), I created a simple linear model using three ranking features derived from relevance scores. Using movie data, I came up with a naive model that computed a relevance score from a title TF\*IDF score, an overview TF\*IDF score, and the user rating of the movie. Our model learned the weight to apply to each score when summing -- similar to the boosts you often apply when doing manual relevance tuning.
#
# What I didn't tell you was I was using Elasticsearch to compute those ranking signals. This blog post I want to take the simple model we derived and make it usable via the [Elasticsearch Learning to Rank plugin](https://github.com/o19s/elasticsearch-learning-to-rank). In a future blog post, we'll load the same model into Solr. This will give you a chance to see a very simple 101 model in action with the two search engine's learning to rank plugins.
#
# ## The signals...
#
# If you recall, learning to rank learns a ranking function as a function of ranking-time signals. Classically these are referred to as "features" when discussing machine learning models. But I like to use *signals* to denote that they're signaling us something about the *relationship* between a query and document. Plus, selfishly, it's what we call ranking-time information in [Relevant Search](http://manning.com/books/relevant-search) to differentiate between the features that exist purely on content or derived from queries.
#
# In this blog post, we'll use the Python Elasticsearch client library, but mostly I'll just be showing off the basic queries I use to derive the signals. I've already loaded the TMDB movie data locally, if you'd like to have this data at your disposal follow the directions in the [Learning to Rank demo README](https://github.com/o19s/elasticsearch-learning-to-rank/tree/master/demo#download-tmdb-data)
#
# Onto the action. Below, you'll see our three queries we use to generate the signal values: `titleSearch`, `overviewSearch`, and `ratingSearch`. The first two are straight-forward [match queries](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-match-query.html). The latter is a [function score query](https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-function-score-query.html) that just returns a movie's rating.

# %%
from elasticsearch import Elasticsearch

keywords="rambo"

titleSearch = {
    "query": {
        "match": {
            "title": keywords
        }
    }
}

overviewSearch = {
    "query": {
        "match": {
            "overview": keywords
        }
    }
}

ratingSearch = {
    "query": {
        "function_score": {
        
            "functions": [
                {"field_value_factor": {
                    "field": "vote_average",
                    "missing": -1   
                }}
            ]
        }
    }
}

es = Elasticsearch()
es.search(index='tmdb', doc_type='movie', body=titleSearch)
es.search(index='tmdb', doc_type='movie', body=overviewSearch)
es.search(index='tmdb', doc_type='movie', body=ratingSearch)
# Out:
# {'_shards': {'failed': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '27915',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': None,
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [{'cast_id': 5,
#        'character': 'Herself (archive footage)',
#        'credit_id': '52fe456dc3a368484e05a2c7',
#        'id': 556903,
#        'name': 'Maria Celeste Arraras',
#        'order': 0,
#        'profile_path': '/mPT80asSjWz8v5Qbzu9Vr1YSPmA.jpg'},
#       {'cast_id': 6,
#        'character': 'Himself (archive footage)',
#        'credit_id': '52fe456dc3a368484e05a2cb',
#        'id': 115863,
#        'name': 'Fidel Castro',
#        'order': 1,
#        'profile_path': '/tPl3cglRXnjKzEu0o6pQ7lO1MNX.jpg'},
#       {'cast_id': 7,
#        'character': 'Himself (archive footage)',
#        'credit_id': '52fe456dc3a368484e05a2cf',
#        'id': 116341,
#        'name': 'Bill Clinton',
#        'order': 2,
#        'profile_path': '/xvAI4AFNFOSblUzLQ5FshY0srAj.jpg'},
#       {'cast_id': 8,
#        'character': 'Himself',
#        'credit_id': '52fe456dc3a368484e05a2d3',
#        'id': 556904,
#        'name': 'Guillermo Armas',
#        'order': 3,
#        'profile_path': None}],
#      'directors': [{'credit_id': '52fe456dc3a368484e05a2b7',
#        'department': 'Directing',
#        'id': 108908,
#        'job': 'Director',
#        'name': 'Josep Maria Domènech',
#        'profile_path': None},
#       {'credit_id': '5871ed51925141355e012c0e',
#        'department': 'Directing',
#        'id': 226483,
#        'job': 'Director',
#        'name': 'Carles Bosch',
#        'profile_path': None}],
#      'genres': [{'id': 99, 'name': 'Documentary'}],
#      'homepage': '',
#      'id': 27915,
#      'imdb_id': 'tt0321376',
#      'mlensId': '41602',
#      'original_language': 'es',
#      'original_title': 'Balseros',
#      'overview': 'The story of Cuban refugees who risked their lives in homemade rafts to reach the United States, and what life is like for those who succeed.',
#      'popularity': 0.001415,
#      'poster_path': '/mM2ICIMkwMzKzQvST0uk0qcrjBT.jpg',
#      'production_companies': [],
#      'production_countries': [{'iso_3166_1': 'ES', 'name': 'Spain'}],
#      'release_date': '2002-04-12',
#      'revenue': 62153,
#      'runtime': 120,
#      'spoken_languages': [{'iso_639_1': 'es', 'name': 'Español'}],
#      'status': 'Released',
#      'tagline': '',
#      'title': 'Cuban Rafters',
#      'title_sent': 'SENTINEL_BEGIN Cuban Rafters',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '175027',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': '/heKADbvV90faiHjmB1muXwAm5R4.jpg',
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [{'cast_id': 2,
#        'character': 'Joan Colby',
#        'credit_id': '52fe4d57c3a36847f825ba65',
#        'id': 103441,
#        'name': 'Ann Harding',
#        'order': 0,
#        'profile_path': '/fhYdh98B0mJVYYvHWPpsEA7kHWb.jpg'},
#       {'cast_id': 3,
#        'character': 'John Fletcher',
#        'credit_id': '52fe4d57c3a36847f825ba69',
#        'id': 32428,
#        'name': 'William Powell',
#        'order': 1,
#        'profile_path': '/83xe0mRdv2GKd3cO72mL2c6lBaC.jpg'},
#       {'cast_id': 4,
#        'character': 'Valerie Colby',
#        'credit_id': '52fe4d57c3a36847f825ba6d',
#        'id': 89009,
#        'name': 'Lucile Browne',
#        'order': 2,
#        'profile_path': '/1WyjR3Lyw7saZ2SfJCQUyVsKrAW.jpg'},
#       {'cast_id': 5,
#        'character': 'Col. Sam Colby',
#        'credit_id': '52fe4d57c3a36847f825ba71',
#        'id': 81934,
#        'name': 'Henry Stephenson',
#        'order': 3,
#        'profile_path': '/wZgaeGbsFPCWfbnQJemCcpPCNAo.jpg'},
#       {'cast_id': 6,
#        'character': 'Monica Page',
#        'credit_id': '52fe4d57c3a36847f825ba75',
#        'id': 145832,
#        'name': 'Lilian Bond',
#        'order': 4,
#        'profile_path': '/15Lq4g2JPMEH98NNYRPwAWRTzLa.jpg'},
#       {'cast_id': 7,
#        'character': 'Dennis Moore',
#        'credit_id': '52fe4d57c3a36847f825ba79',
#        'id': 99330,
#        'name': 'George Meeker',
#        'order': 5,
#        'profile_path': '/66Z6noR6WSvytzwaxt65X5XW2E1.jpg'},
#       {'cast_id': 8,
#        'character': 'Freeman',
#        'credit_id': '52fe4d57c3a36847f825ba7d',
#        'id': 5832,
#        'name': 'Reginald Owen',
#        'order': 6,
#        'profile_path': '/bgtpAl7ICrDyJQzjglLiVY6tlMw.jpg'},
#       {'cast_id': 11,
#        'character': 'Eleanor Weston',
#        'credit_id': '549d3608925141312300552c',
#        'id': 87858,
#        'name': 'Kay Hammond',
#        'order': 7,
#        'profile_path': '/nWZlnfCRIVCjIKBe7LVRWMbQWNP.jpg'},
#       {'cast_id': 12,
#        'character': 'Leonard Weston',
#        'credit_id': '549d361b9251414bb2003c5f',
#        'id': 1204239,
#        'name': 'Leigh Allen',
#        'order': 8,
#        'profile_path': None},
#       {'cast_id': 13,
#        'character': 'Farley Drake',
#        'credit_id': '549d362cc3a3682f1e005626',
#        'id': 133276,
#        'name': 'Hugh Huntley',
#        'order': 9,
#        'profile_path': None},
#       {'cast_id': 14,
#        'character': 'Postmaster General',
#        'credit_id': '549d363e9251415dc1004a57',
#        'id': 589217,
#        'name': 'Wallis Clark',
#        'order': 10,
#        'profile_path': '/spMgNeu8LM30dVBO2iYZUJsKyuS.jpg'},
#       {'cast_id': 15,
#        'character': 'Bruno (as Fredric Santley)',
#        'credit_id': '549d36509251415dc1004a59',
#        'id': 1271019,
#        'name': 'Fred Santley',
#        'order': 11,
#        'profile_path': None},
#       {'cast_id': 16,
#        'character': 'Crab Counterman (uncredited)',
#        'credit_id': '549d3663c3a3685542002155',
#        'id': 30530,
#        'name': 'Irving Bacon',
#        'order': 12,
#        'profile_path': '/oI6h1L5HvvXLacBIlKoHcXrHbhI.jpg'}],
#      'directors': [{'credit_id': '52fe4d57c3a36847f825ba61',
#        'department': 'Directing',
#        'id': 31497,
#        'job': 'Director',
#        'name': 'John Cromwell',
#        'profile_path': '/1osYpgUy3zABKeFRjyBX0K4qcY9.jpg'}],
#      'genres': [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}],
#      'homepage': '',
#      'id': 175027,
#      'imdb_id': 'tt0023960',
#      'mlensId': '52326',
#      'original_language': 'en',
#      'original_title': 'Double Harness',
#      'overview': 'After tricking him into marriage, a woman (Ann Harding) tries to win the love of her philandering husband (William Powell).',
#      'popularity': 0.031001,
#      'poster_path': '/qSJS4XZ6hms8mHcTXQgHugYTRoW.jpg',
#      'production_companies': [{'id': 6, 'name': 'RKO Radio Pictures'}],
#      'production_countries': [{'iso_3166_1': 'US',
#        'name': 'United States of America'}],
#      'release_date': '1933-07-21',
#      'revenue': 0,
#      'runtime': 69,
#      'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#      'status': 'Released',
#      'tagline': 'The story of a temporary marriage',
#      'title': 'Double Harness',
#      'title_sent': 'SENTINEL_BEGIN Double Harness',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '115427',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': None,
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [{'cast_id': 4,
#        'character': 'Macbeth',
#        'credit_id': '52fe4b6bc3a36847f8202d37',
#        'id': 42077,
#        'name': 'György Cserhalmi',
#        'order': 0,
#        'profile_path': '/wo9vVqUEiK5aAOszEqoShKV0O2F.jpg'},
#       {'cast_id': 5,
#        'character': 'Lady Macbeth',
#        'credit_id': '52fe4b6bc3a36847f8202d3b',
#        'id': 1086293,
#        'name': 'Erzsébet Kútvölgyi',
#        'order': 1,
#        'profile_path': '/4LM7DhIdkit1mnhDWh4VNH8Gxqz.jpg'},
#       {'cast_id': 6,
#        'character': '',
#        'credit_id': '52fe4b6bc3a36847f8202d3f',
#        'id': 1086294,
#        'name': 'Ferenc Bencze',
#        'order': 2,
#        'profile_path': None},
#       {'cast_id': 7,
#        'character': '',
#        'credit_id': '52fe4b6bc3a36847f8202d43',
#        'id': 82364,
#        'name': 'Imre Csuja',
#        'order': 3,
#        'profile_path': '/7Fhtm6tPuWB1hnyBXHEVv5xlvqU.jpg'},
#       {'cast_id': 19,
#        'character': '',
#        'credit_id': '5589a750c3a368054500432a',
#        'id': 402999,
#        'name': 'János Derzsi',
#        'order': 5,
#        'profile_path': '/54UKQ3vBd28sJwzyPFUKs1OqpoJ.jpg'},
#       {'cast_id': 9,
#        'character': '',
#        'credit_id': '52fe4b6bc3a36847f8202d4b',
#        'id': 56293,
#        'name': 'István Dégi',
#        'order': 6,
#        'profile_path': None},
#       {'cast_id': 10,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d4f',
#        'id': 1042223,
#        'name': 'Pál Hetényi',
#        'order': 7,
#        'profile_path': None},
#       {'cast_id': 11,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d53',
#        'id': 125402,
#        'name': 'Tamás Jordán',
#        'order': 8,
#        'profile_path': '/eSyd7PQAJbS3VMjqAav2ymn9rSD.jpg'},
#       {'cast_id': 12,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d57',
#        'id': 1078344,
#        'name': 'Attila Kaszás',
#        'order': 9,
#        'profile_path': '/aS1lIzNxjpe3Ea4wdxnMR0kpzJV.jpg'},
#       {'cast_id': 13,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d5b',
#        'id': 1086295,
#        'name': 'Gyula Maár',
#        'order': 10,
#        'profile_path': None},
#       {'cast_id': 14,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d5f',
#        'id': 53779,
#        'name': 'Djoko Rosic',
#        'order': 11,
#        'profile_path': None},
#       {'cast_id': 15,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d63',
#        'id': 1086296,
#        'name': 'József Ruszt',
#        'order': 12,
#        'profile_path': None},
#       {'cast_id': 16,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d67',
#        'id': 1086297,
#        'name': 'Géza Rácz',
#        'order': 13,
#        'profile_path': None},
#       {'cast_id': 17,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d6b',
#        'id': 49673,
#        'name': 'Miklós Székely B.',
#        'order': 14,
#        'profile_path': None},
#       {'cast_id': 18,
#        'character': '',
#        'credit_id': '52fe4b6cc3a36847f8202d6f',
#        'id': 1086298,
#        'name': 'János Ács',
#        'order': 15,
#        'profile_path': None}],
#      'directors': [{'credit_id': '52fe4b6bc3a36847f8202d27',
#        'department': 'Directing',
#        'id': 85637,
#        'job': 'Director',
#        'name': 'Béla Tarr',
#        'profile_path': '/l8YNXkVlsmfspleRPJsVdPZbZYx.jpg'}],
#      'genres': [{'id': 18, 'name': 'Drama'}],
#      'homepage': '',
#      'id': 115427,
#      'imdb_id': 'tt0292081',
#      'mlensId': '86829',
#      'original_language': 'hu',
#      'original_title': 'Macbeth',
#      'overview': 'A Hungarian TV version of the play shot in just two takes.',
#      'popularity': 5e-06,
#      'poster_path': '/MXwwQjLWEfpPiY33XUqIRsOKk.jpg',
#      'production_companies': [],
#      'production_countries': [{'iso_3166_1': 'HU', 'name': 'Hungary'}],
#      'release_date': '1982-01-01',
#      'revenue': 0,
#      'runtime': 72,
#      'spoken_languages': [{'iso_639_1': 'hu', 'name': 'Magyar'}],
#      'status': 'Released',
#      'tagline': '',
#      'title': 'Macbeth',
#      'title_sent': 'SENTINEL_BEGIN Macbeth',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '96451',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': '/zj415liRffeCusz8m7dhEDT4Zw.jpg',
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [],
#      'directors': [{'credit_id': '52fe49b49251416c750d0955',
#        'department': 'Directing',
#        'id': 5281,
#        'job': 'Director',
#        'name': 'Spike Lee',
#        'profile_path': '/2LmTDMa6ewhkyP4LDBWFdDYDfUv.jpg'}],
#      'genres': [{'id': 99, 'name': 'Documentary'}],
#      'homepage': '',
#      'id': 96451,
#      'imdb_id': 'tt1587373',
#      'mlensId': '80137',
#      'original_language': 'en',
#      'original_title': "If God Is Willing and da Creek Don't Rise",
#      'overview': "In 2006, director Spike Lee created an astonishing record of the cataclysmic effects of Hurricane Katrina on the city of New Orleans with his epic award-winning documentary, When the Levees Broke. Five years later, Lee returns to New Orleans, to see how the ambitious plans to reinvent the Crescent City were playing out. He finds a patchwork of hope and heartache just as a new disaster unfolds. The four-hour documentary is a continuation of the heart-rending story of destruction and rebirth of America's most unique city.",
#      'popularity': 0.000942,
#      'poster_path': '/d0eQy5xYxZnJsVYhRic8aIX0lA2.jpg',
#      'production_companies': [{'id': 4319,
#        'name': '40 Acres & A Mule Filmworks'}],
#      'production_countries': [{'iso_3166_1': 'US',
#        'name': 'United States of America'}],
#      'release_date': '2010-08-23',
#      'revenue': 0,
#      'runtime': 255,
#      'spoken_languages': [],
#      'status': 'Released',
#      'tagline': '',
#      'title': "If God Is Willing and da Creek Don't Rise",
#      'title_sent': "SENTINEL_BEGIN If God Is Willing and da Creek Don't Rise",
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '148408',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': None,
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [{'cast_id': 2,
#        'character': '',
#        'credit_id': '52fe4bca9251416c7510e059',
#        'id': 544842,
#        'name': 'Giovanna Claudia Mongino',
#        'order': 0,
#        'profile_path': None},
#       {'cast_id': 3,
#        'character': '',
#        'credit_id': '52fe4bca9251416c7510e05d',
#        'id': 1127788,
#        'name': 'Luciano Piergiovanni',
#        'order': 1,
#        'profile_path': None}],
#      'directors': [{'credit_id': '52fe4bca9251416c7510e055',
#        'department': 'Directing',
#        'id': 27213,
#        'job': 'Director',
#        'name': 'Ermanno Olmi',
#        'profile_path': '/kF6ueDBkIFUb78Zo5dvCvnAAxqQ.jpg'}],
#      'genres': [{'id': 18, 'name': 'Drama'}],
#      'homepage': '',
#      'id': 148408,
#      'imdb_id': 'tt0412608',
#      'mlensId': '96905',
#      'original_language': 'en',
#      'original_title': 'La cotta',
#      'overview': 'Olmi’s 1967 short about a young boy’s first love.',
#      'popularity': 0.000146,
#      'poster_path': '/GSc6bzHXjPCv0CoEFH5A6GoNg1.jpg',
#      'production_companies': [],
#      'production_countries': [],
#      'release_date': '1967-01-01',
#      'revenue': 0,
#      'runtime': 49,
#      'spoken_languages': [{'iso_639_1': 'it', 'name': 'Italiano'}],
#      'status': 'Released',
#      'tagline': '',
#      'title': 'La cotta',
#      'title_sent': 'SENTINEL_BEGIN La cotta',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '269518',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': None,
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [],
#      'directors': [{'credit_id': '53711531c3a368701e000322',
#        'department': 'Directing',
#        'id': 133090,
#        'job': 'Director',
#        'name': 'José Luis Guerin',
#        'profile_path': None}],
#      'genres': [{'id': 99, 'name': 'Documentary'}],
#      'homepage': '',
#      'id': 269518,
#      'imdb_id': 'tt1146298',
#      'mlensId': '89664',
#      'original_language': 'es',
#      'original_title': 'Unas fotos en la ciudad de Sylvia',
#      'overview': 'This remarkable companion piece to In the City of Sylvia offers a compendium of images recorded by Guerín in Strasbourg while searching for the traces of a (fictional?) brief encounter some years earlier with a young woman named Sylvia.',
#      'popularity': 0.000496,
#      'poster_path': '/2KZO9nvSFpOdR35uNFUw9mc0RIR.jpg',
#      'production_companies': [],
#      'production_countries': [],
#      'release_date': '2007-10-02',
#      'revenue': 0,
#      'runtime': 67,
#      'spoken_languages': [{'iso_639_1': 'es', 'name': 'Español'}],
#      'status': 'Released',
#      'tagline': '',
#      'title': 'Some Photos in the City of Sylvia',
#      'title_sent': 'SENTINEL_BEGIN Some Photos in the City of Sylvia',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '127092',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': None,
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [{'cast_id': 2,
#        'character': 'Nick Hezard',
#        'credit_id': '52fe4af0c3a368484e16eddd',
#        'id': 36913,
#        'name': 'Luc Merenda',
#        'order': 0,
#        'profile_path': '/uSM73n88qekWYfcReVv9CROsvH6.jpg'},
#       {'cast_id': 3,
#        'character': 'Robert Clark',
#        'credit_id': '573679ba9251410b27001645',
#        'id': 5248,
#        'name': 'Lee J. Cobb',
#        'order': 1,
#        'profile_path': '/535dOk8eUI97esLMunIXdG58jUu.jpg'},
#       {'cast_id': 4,
#        'character': '',
#        'credit_id': '573679e1925141136e0015cc',
#        'id': 4961,
#        'name': 'Gabriele Ferzetti',
#        'order': 2,
#        'profile_path': '/vmalA5oHaMOFAKVccBBY21z7Eju.jpg'},
#       {'cast_id': 5,
#        'character': 'Robert Clarke',
#        'credit_id': '573679f29251410b2100160d',
#        'id': 5248,
#        'name': 'Lee J. Cobb',
#        'order': 3,
#        'profile_path': '/535dOk8eUI97esLMunIXdG58jUu.jpg'},
#       {'cast_id': 6,
#        'character': '',
#        'credit_id': '57367a4892514113bd001565',
#        'id': 9921,
#        'name': 'Luciana Paluzzi',
#        'order': 4,
#        'profile_path': '/wm2kQjIeg0wAfE4SYA9LqUu3fwA.jpg'},
#       {'cast_id': 7,
#        'character': '',
#        'credit_id': '57367a86c3a3687e2f001769',
#        'id': 46636,
#        'name': 'Dagmar Lassander',
#        'order': 5,
#        'profile_path': '/z5sdtXsr0hUAUtiIXzb94FS511s.jpg'}],
#      'directors': [{'credit_id': '52fe4af0c3a368484e16edd9',
#        'department': 'Directing',
#        'id': 49892,
#        'job': 'Director',
#        'name': 'Fernando Di Leo',
#        'profile_path': '/frrl8Sd6WvQk1obCClj7bqMFX1P.jpg'}],
#      'genres': [{'id': 80, 'name': 'Crime'}],
#      'homepage': '',
#      'id': 127092,
#      'imdb_id': 'tt0074137',
#      'mlensId': '128826',
#      'original_language': 'en',
#      'original_title': 'Gli amici di Nick Hezard',
#      'overview': "Nick Hezard, a young con man, wants to avenge the death of a friend of his and organizes a swindle trying to cheat Robert Turner, an American businessman he thinks responsible for his friend's death. He succeeds in getting a hundred thousand swiss francs and uses them to carry out the second part of his plan.",
#      'popularity': 0.0008,
#      'poster_path': '/bklS20rjK74mzfY3DDWWTRjhfZV.jpg',
#      'production_companies': [],
#      'production_countries': [],
#      'release_date': '1976-09-14',
#      'revenue': 0,
#      'runtime': 94,
#      'spoken_languages': [{'iso_639_1': 'it', 'name': 'Italiano'}],
#      'status': 'Rumored',
#      'tagline': '',
#      'title': 'Nick the Sting',
#      'title_sent': 'SENTINEL_BEGIN Nick the Sting',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '62491',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': '/8N8pWt7G3E1BHigYlmi0zmtYt17.jpg',
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [{'cast_id': 4,
#        'character': 'Carlo',
#        'credit_id': '52fe4680c3a368484e0941cd',
#        'id': 89193,
#        'name': 'Carlo Verdone',
#        'order': 0,
#        'profile_path': '/6Llxs7g6cjPrOVnp2omFhpEsbNy.jpg'},
#       {'cast_id': 5,
#        'character': 'Silvia',
#        'credit_id': '52fe4680c3a368484e0941d1',
#        'id': 27163,
#        'name': 'Ornella Muti',
#        'order': 1,
#        'profile_path': '/g8B53naAKyK1CWhi4xZ2B5eWqo0.jpg'},
#       {'cast_id': 6,
#        'character': 'Serena',
#        'credit_id': '52fe4680c3a368484e0941d5',
#        'id': 124620,
#        'name': 'Elena Sofia Ricci',
#        'order': 2,
#        'profile_path': '/k0qruKp0zcZ3QCUW6LequPK8T7Z.jpg'},
#       {'cast_id': 7,
#        'character': 'Nadia',
#        'credit_id': '52fe4680c3a368484e0941d9',
#        'id': 150617,
#        'name': 'Mariangela Giordano',
#        'order': 3,
#        'profile_path': '/5GSu8PyEnzVBAPu0mcA4a9jN7pe.jpg'}],
#      'directors': [{'credit_id': '52fe4680c3a368484e0941bd',
#        'department': 'Directing',
#        'id': 89193,
#        'job': 'Director',
#        'name': 'Carlo Verdone',
#        'profile_path': '/6Llxs7g6cjPrOVnp2omFhpEsbNy.jpg'}],
#      'genres': [{'id': 35, 'name': 'Comedy'}],
#      'homepage': '',
#      'id': 62491,
#      'imdb_id': 'tt0093274',
#      'mlensId': '120885',
#      'original_language': 'it',
#      'original_title': 'Io e mia sorella',
#      'overview': "Carlo is a responsible sibling who deals with his black-sheep sister Silvia in this situation comedy. When Silvia returns after many years to attend her mother's funeral, Carlo deals with the fallout caused by her many love affairs. Carlo is convinced to kidnap Silvia's child whom she left in a Hungarian children's home, but she soon abandons Carlo and the baby when she takes up with a British rock star.",
#      'popularity': 4e-06,
#      'poster_path': '/j1AvDadbw5ASimUmOhZVLzMszlq.jpg',
#      'production_companies': [{'id': 18283, 'name': 'C.G. Silver Film'},
#       {'id': 44406, 'name': 'Rai 1'}],
#      'production_countries': [{'iso_3166_1': 'IT', 'name': 'Italy'}],
#      'release_date': '1987-12-19',
#      'revenue': 0,
#      'runtime': 110,
#      'spoken_languages': [{'iso_639_1': 'it', 'name': 'Italiano'}],
#      'status': 'Released',
#      'tagline': '',
#      'title': 'My Sister and I',
#      'title_sent': 'SENTINEL_BEGIN My Sister and I',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '74417',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': '/7inIetUOXG7IiWAdcUwls0fLKgR.jpg',
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [{'cast_id': 2,
#        'character': '',
#        'credit_id': '52fe48c9c3a368484e10b079',
#        'id': 32377,
#        'name': 'Enrico Maria Salerno',
#        'order': 0,
#        'profile_path': '/tODadFPOVHkAbu8wqyHcZOpG4Ek.jpg'},
#       {'cast_id': 3,
#        'character': '',
#        'credit_id': '52fe48c9c3a368484e10b07d',
#        'id': 5248,
#        'name': 'Lee J. Cobb',
#        'order': 1,
#        'profile_path': '/535dOk8eUI97esLMunIXdG58jUu.jpg'},
#       {'cast_id': 4,
#        'character': '',
#        'credit_id': '52fe48c9c3a368484e10b081',
#        'id': 9762,
#        'name': 'Jean Sorel',
#        'order': 2,
#        'profile_path': '/3twOMDVpgK6psPN7n3mwpwAvzF9.jpg'},
#       {'cast_id': 5,
#        'character': '',
#        'credit_id': '53d8e1ea0e0a261c810022a7',
#        'id': 9921,
#        'name': 'Luciana Paluzzi',
#        'order': 3,
#        'profile_path': '/wm2kQjIeg0wAfE4SYA9LqUu3fwA.jpg'}],
#      'directors': [{'credit_id': '52fe48c9c3a368484e10b075',
#        'department': 'Directing',
#        'id': 264596,
#        'job': 'Director',
#        'name': 'Roberto Infascelli',
#        'profile_path': None}],
#      'genres': [{'id': 80, 'name': 'Crime'}],
#      'homepage': '',
#      'id': 74417,
#      'imdb_id': 'tt0194268',
#      'mlensId': '118510',
#      'original_language': 'fr',
#      'original_title': 'La polizia sta a guardare',
#      'overview': 'In early seventies Italy, plagued by criminality and political terrorism, a fearless police commissioner is sent to restore law and order in a northern industrial town devastated by a recent wave of violence and kidnappings..',
#      'popularity': 0.000137,
#      'poster_path': '/mpJM5IjG47QCv3kGuQ8Mqfk0Jmb.jpg',
#      'production_companies': [{'id': 15324, 'name': 'Primex Italiana'}],
#      'production_countries': [{'iso_3166_1': 'IT', 'name': 'Italy'}],
#      'release_date': '1973-11-16',
#      'revenue': 0,
#      'runtime': 95,
#      'spoken_languages': [{'iso_639_1': 'it', 'name': 'Italiano'}],
#      'status': 'Released',
#      'tagline': 'the great kidnapping',
#      'title': 'The Great Kidnapping',
#      'title_sent': 'SENTINEL_BEGIN The Great Kidnapping',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'},
#    {'_id': '114524',
#     '_index': 'tmdb',
#     '_score': 10.0,
#     '_source': {'adult': False,
#      'backdrop_path': None,
#      'belongs_to_collection': None,
#      'budget': 0,
#      'cast': [],
#      'directors': [{'credit_id': '52fe4b4dc3a36847f81fd189',
#        'department': 'Directing',
#        'id': 109402,
#        'job': 'Director',
#        'name': 'Rob Epstein',
#        'profile_path': None},
#       {'credit_id': '52fe4b4dc3a36847f81fd18f',
#        'department': 'Directing',
#        'id': 109403,
#        'job': 'Director',
#        'name': 'Jeffrey Friedman',
#        'profile_path': None}],
#      'genres': [],
#      'homepage': '',
#      'id': 114524,
#      'imdb_id': 'tt0097099',
#      'mlensId': '26655',
#      'original_language': 'en',
#      'original_title': 'Common Threads: Stories from the Quilt',
#      'overview': 'In the late 1970’s, a mysterious new disease began infecting and killing gay men. Common Threads tells the powerful story of the first decade of the AIDS epidemic, as told through the lives of five very diverse individuals who shared a common fate. Using the monumental NAMES Project AIDS Memorial Quilt as its central metaphor, the film weaves together personal memories and television news stories to expose the U.S. government’s failure to respond to the growing epidemic, and the vibrant protest movement that was born as a result. From the Olympic athlete to the inner-city recovering drug addict, from the conservative naval commander to the New York gay activist to the 11-year-old suburban boy with hemophilia, the film uses intimate details to tell an epic story of love, loss, anger and healing.',
#      'popularity': 1.2e-05,
#      'poster_path': '/sTKE5bzSMnsGoY3BwdMoRK7LuAL.jpg',
#      'production_companies': [{'id': 5448, 'name': 'New Yorker Films'},
#       {'id': 5842, 'name': 'Sandollar Productions'}],
#      'production_countries': [{'iso_3166_1': 'US',
#        'name': 'United States of America'}],
#      'release_date': '1989-12-01',
#      'revenue': 0,
#      'runtime': 79,
#      'spoken_languages': [{'iso_639_1': 'en', 'name': 'English'}],
#      'status': 'Released',
#      'tagline': '',
#      'title': 'Common Threads: Stories from the Quilt',
#      'title_sent': 'SENTINEL_BEGIN Common Threads: Stories from the Quilt',
#      'video': False,
#      'vote_average': 10.0,
#      'vote_count': 1},
#     '_type': 'movie'}],
#   'max_score': 10.0,
#   'total': 27008},
#  'timed_out': False,
#  'took': 6}

# %% [markdown]
# If you recall, these three features were gathered for a set of judgments. Judgments let us know how relevant a document is for a query. So Rambo is a "4" (exact match) for the keyword search "rambo." Conversely "Rocky and Bullwininkle" is a 0 (not at all relevant) for a "Rambo" query. With enough judgments, we logged the relevance scores of the above queries for the documents that were judged. This gave us a training set that looked like:
#
# ```
# titleScore,overviewScore,movieRating,comment
# 4,12.28,9.82,6.40,# 7555	rambo@Rambo
# 0,0.00,10.76,7.10,# 1368	rambo@First Blood
# ```
#
# In that blog post, we used `sk-learn` to run linear regression to learn which signals best predicted the resulting relevance grade. We came up with a model with a weight for each and a y-intercept. This model was:

# %%
coefs = [ 0.04999419,  0.22958357,  0.00573909] # each signals weight
yIntercept = 0.97040804634516986

# %% [markdown]
# ## Uploading our Linear model to Elasticsearch
#
# The Elasticsearch learning to rank plugin uses a scripting format known as `ranklib` to encode models. Following the [documentation for the ranklib scripting language](https://docs.google.com/document/d/1DL_Z40eGG3r_BVOoVYpBRb3k2qWONRf_w02FfORtiSU/edit#) we know we can encode a linear model that looks like:
#
# ```
# ## Linear Regression
# 0:<y-intercept> 1:<coef1> 2:<coef2> 3:<coef3> ...
# ```
#
# So in Python code, we can format our model above in that format:

# %%
linearModel = """ ## Linear Regression
0:0.97040804634516986 1:0.04999419 2:0.229585357 3:0.00573909
"""

# %% [markdown]
# Following the [documentation for the Learning to Rank Plugin]() we can upload this model as a ranklib script, and give it a name.

# %%
es.put_script(lang='ranklib', id='our_silly_model', body={'script': linearModel})
# Out:
# {'acknowledged': True}

# %% [markdown]
# Elasticsearch has acknowledged our upload. Great! Now we should be able to execute a simple query!

# %% [markdown]
# ## How do we construct a query that uses the model?
#
# You almost always want to run a learning to rank model in a rescore query, but the TMDB data set isn't huge. We can use it directly with only a few hundred milliseconds to evaluate over the whole corpus. This is fun, because it let's us informally evaluate how well our model is doing.
#
# To query with the model, we create a function that runs the ltr query. Remember the model we built computes a relevance score for a document from three inputs that relate to the query and document:
#
# - The keyword's title TF\*IDF score
# - The keyword's overview TF\*IDF score
# - The movie's rating
#
# To compute the first two, we need to run the `titleSearch` and `overviewSearch` above for our current keywords. So we need to pass our model a version of these queries with the current keywords. That's what happens first in the function below. We inject our keywords into the inputs that are query-dependent. Then we add our `ratingSearch` that's only document dependent.
#
# These three queries are scored per document are then fed into the linear model. Remember [last time](http://opensourceconnections.com/blog/2017/04/01/learning-to-rank-linear-models/) this model is simple: each coefficient is just a weight on each signal's score. The model is simply a weighted sum of the scores of `titleSearch`, `overviewSearch`, and `ratingSearch` using coefficients as the weight!

# %%
def runLtrQuery(keywords):

    # Plugin our keywords
    titleSearch['query']['match']['title'] = keywords
    overviewSearch['query']['match']['overview'] = keywords
    
    # Format query    
    ltrQuery = {
        "query": {
            "ltr": {
                "model": {
                    "stored": "our_silly_model"
                },
                "features": [titleSearch['query'], overviewSearch['query'], ratingSearch['query']]

            }
        },
        "size": 3

    }
    
    # Search and print results!
    results = es.search(index='tmdb', doc_type='movie', body=ltrQuery)
    for result in results['hits']['hits']:
        if 'title' in result['_source']:
            print(result['_source']['title'])
        else:
            print("Movie %s (unknown title)" % result['_id'])

# %% [markdown]
# ## Taking the model on a test spin...

# %% [markdown]
# With this function in place, let's run some searches! First a simple title searche:

# %%
runLtrQuery('Forrest Gump')
# Out:
# Forrest Gump
# Dead Men Don't Wear Plaid
# Maniac Cop

# %% [markdown]
# Hey, not too shabby! How long will our luck go, let's try another one:

# %%
runLtrQuery('Robin Hood')
# Out:
# Robin Hood: Men in Tights
# Welcome to Sherwood! The Story of 'The Adventures of Robin Hood'
# Robin Hood

# %% [markdown]
# Wow lucky again. It's almost like these aren't lucky guesses but rather a prescient author is selecting examples that they know will look good! Ok, now let's try something closer to home: a Stallone Movie:

# %%
runLtrQuery('Rambo')
# Out:
# Rambo III
# Rambo
# Rambo: First Blood Part II

# %% [markdown]
# Err, not bad, but a bit off the mark... Well this is actually a case, like we talked about before, involving the nuance that the linear model can fail to capture. The linear model just knows "more title score is good!". But in *this* case, First Blood should be closer to the top. It *was* the original Rambo movie! Moreover Rambo III shouldn't really before just Rambo.
#
# Still, not bad for 40 odd examples of training data!
#
# Let's try something where we *don't* know the title. Like an example from Relevant Search `basketball with cartoon aliens`. Here we're grasping at straws. Hoping "Space Jam", a movie where Michael Jordan saves the world by playing aliens at basketball, comes up first:

# %%
runLtrQuery('basketball with cartoon aliens')
# Out:
# Aliens in the Attic
# Above the Rim
# Meet Dave

# %% [markdown]
# Sadly, Not even close! To be fair,  we didn't show our training process examples of this use case. Most of our examples were direct, known-title navigational searches. This just goes to show you how it's important to get a broad set of representative samples across how your users search for learning to rank to work well.
#
# It also continues to demonstrate how the linear model struggles with nuance. Other models like gradient boosting (ala LambdaMART) can grok nuance faster, and aren't constrained to our boring linear definitions of functions. We'll see how these models work in future blog posts.

# %% [markdown]
# ## Next up Solr!
#
# One of my colleagues will be taking Solr learning to rank out for a test spin for you. A simple linear model is very easy to understand, so it's fun for these little test-spins.
#
# I'd love to hear from you. If you'd like our help evaluating a learning to rank solution for your business, please [get in touch](mailto:TalkToUs@opensourceconnections.com)! And I'm always eager for feedback on these posts. Please let me know if I can learn a few things fro
